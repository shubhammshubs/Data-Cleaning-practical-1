# %%
import pandas as pd
import numpy as np

# %%
sales_2017 = pd.read_csv("Sales Transactions-2017.csv")
sales_2017
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
 sales_2018 = pd.read_csv("Sales Transactions-2018.csv")
sales_2018
# Out:
#              Date   Voucher        Party            Product           Qty  \
# 0        1/4/2018   Sal:146         TP13  SILVER POUCH 9*12            50
# 1        1/4/2018   Sal:146         TP13             RUBBER             5
# 2        1/4/2018   Sal:146         TP13   DURGA 10*12 Blue      1,600.00
# 3        1/4/2018   Sal:146         TP13   DURGA 13*16 BLUE           400
# 4        1/4/2018   Sal:146         TP13    10*12 SARAS-NAT           600
# ...           ...       ...          ...                ...           ...
# 44735  31/03/2019  Sal:9610  HAMPI FOODS        SPOON SOOFY           200
# 44736         NaN       NaN          NaN                NaN           NaN
# 44737         NaN       NaN          NaN                NaN           NaN
# 44738         NaN   Total            NaN                NaN    666,056.00
# 44739         NaN   Total            NaN                NaN  7,097,803.00
#
#                 Rate           Gross        Disc  Voucher Amount
# ...

# %%
 sales_2019 = pd.read_csv("Sales Transactions-2019.csv")
sales_2019
# Out:
#              Date   Voucher            Party         Product           Qty  \
# 0        1/4/2019   Sal:687  BALAJI PLASTICS   DONA-VAI-9100             1
# 1        1/4/2019   Sal:687  BALAJI PLASTICS  SMART BOUL(48)             1
# 2        1/4/2019   Sal:688  BALAJI PLASTICS      Vishnu Ice           110
# 3                                       28/3                             0
# 4        1/4/2019   Sal:689  BALAJI PLASTICS     100LEAF -SP             3
# ...           ...       ...              ...             ...           ...
# 19171  10/10/2019  Sal:4935        K.SRIHARI  13*16 WHITE RK           400
# 19172         NaN       NaN              NaN             NaN           NaN
# 19173         NaN       NaN              NaN             NaN           NaN
# 19174         NaN   Total                NaN             NaN     99,284.90
# 19175         NaN   Total                NaN             NaN  2,710,193.00
#
#                Rate          Gross        Disc Voucher Amount
# ...

# %% [markdown]
# ## Concatinating the datas

# %%
clean_data = pd.concat([sales_2017,sales_2018,sales_2019])
clean_data
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
clean_data.shape
# Out:
# (111206, 9)

# %%
clean_data.isna().sum()
# Out:
# Date               12591
# Voucher            12557
# Party                 40
# Product            12591
# Qty                12557
# Rate               12558
# Gross              12558
# Disc              105609
# Voucher Amount     83646
# dtype: int64

# %%
clean_data.dtypes
# Out:
# Date              object
# Voucher           object
# Party             object
# Product           object
# Qty               object
# Rate              object
# Gross             object
# Disc              object
# Voucher Amount    object
# dtype: object

# %% [markdown]
# ## Droping the columns containing more null values

# %%
clean_data.drop('Disc',axis=1,inplace=True)

# %%
del clean_data['Gross']         # we can also use delete function to drop the column

# %%
clean_data.drop('Voucher Amount',axis=1,inplace=True)

# %%
clean_data.head(50)
# Out:
#         Date   Voucher                Party              Product       Qty  \
# 0   1/4/2017     Sal:1     SOLANKI PLASTICS        DONA-VAI-9100         2
# 1   1/4/2017     Sal:1     SOLANKI PLASTICS      LITE FOAM(1200)         6
# 2   1/4/2017     Sal:2   SARNESWARA TRADERS    VISHNU CHOTA WINE       500
# 3   1/4/2017     Sal:2   SARNESWARA TRADERS      LITE FOAM(1200)         6
# 4   1/4/2017     Sal:2   SARNESWARA TRADERS        DONA-VAI-9100         5
# 5   1/4/2017     Sal:2   SARNESWARA TRADERS   CLASSIC ENJOY(750)         1
# 6   1/4/2017   Sal:898                 Lock         Vishnu 250ml       100
# 7   1/4/2017   Sal:898                 Lock      BLACK DOG-350ML       100
# 8                       khader vali late en
# 9                                       try
# 10  1/4/2017  Sal:2497  VAMSI KRISHNA FANCY          Loose Items         1
# 11       NaN       NaN               #NAME?                  NaN       NaN
# 12                              DUMMY ENTRY
# ...

# %% [markdown]
# ## droping null values

# %%
clean_data.dropna(axis=0,inplace=True)        # i have deleted the NaN entrys still some blank values are remaining

# %%
clean_data.replace(' ',np.nan,inplace=True)    # so replacing those blank cells with NaN

# %%
clean_data.head(50)
# Out:
#         Date   Voucher                Party              Product       Qty  \
# 0   1/4/2017     Sal:1     SOLANKI PLASTICS        DONA-VAI-9100         2
# 1   1/4/2017     Sal:1     SOLANKI PLASTICS      LITE FOAM(1200)         6
# 2   1/4/2017     Sal:2   SARNESWARA TRADERS    VISHNU CHOTA WINE       500
# 3   1/4/2017     Sal:2   SARNESWARA TRADERS      LITE FOAM(1200)         6
# 4   1/4/2017     Sal:2   SARNESWARA TRADERS        DONA-VAI-9100         5
# 5   1/4/2017     Sal:2   SARNESWARA TRADERS   CLASSIC ENJOY(750)         1
# 6   1/4/2017   Sal:898                 Lock         Vishnu 250ml       100
# 7   1/4/2017   Sal:898                 Lock      BLACK DOG-350ML       100
# 8        NaN       NaN  khader vali late en                  NaN       NaN
# 9        NaN       NaN                  try                  NaN       NaN
# 10  1/4/2017  Sal:2497  VAMSI KRISHNA FANCY          Loose Items         1
# ...

# %%
clean_data.dropna(axis=0,inplace=True)          # again using drop fun tho delete those NaN values

# %%
clean_data
# Out:
#              Date   Voucher               Party              Product  Qty  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...       ...                 ...                  ...  ...
# 19167  10/10/2019  Sal:4935           K.SRIHARI         16*20(100-W)  140
# 19168  10/10/2019  Sal:4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 19169  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 19170  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK  800
# 19171  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK  400
#
#            Rate
# 0      1,690.00
# 1      1,620.00
# 2            23
# ...

# %%
clean_data.isna().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       0
# dtype: int64

# %% [markdown]
# ## Now the index is not in sorted format so creating new index and delting the orignal index

# %%
clean_data.head(50)
# Out:
#         Date   Voucher                Party              Product       Qty  \
# 0   1/4/2017     Sal:1     SOLANKI PLASTICS        DONA-VAI-9100         2
# 1   1/4/2017     Sal:1     SOLANKI PLASTICS      LITE FOAM(1200)         6
# 2   1/4/2017     Sal:2   SARNESWARA TRADERS    VISHNU CHOTA WINE       500
# 3   1/4/2017     Sal:2   SARNESWARA TRADERS      LITE FOAM(1200)         6
# 4   1/4/2017     Sal:2   SARNESWARA TRADERS        DONA-VAI-9100         5
# 5   1/4/2017     Sal:2   SARNESWARA TRADERS   CLASSIC ENJOY(750)         1
# 6   1/4/2017   Sal:898                 Lock         Vishnu 250ml       100
# 7   1/4/2017   Sal:898                 Lock      BLACK DOG-350ML       100
# 10  1/4/2017  Sal:2497  VAMSI KRISHNA FANCY          Loose Items         1
# 13  1/4/2017  Sal:9263  VAMSI KRISHNA FANCY          Loose Items         1
# 16  1/4/2017  Sal:9545                  Vkp          Loose Items         1
# ...

# %%
clean_data.reset_index(inplace=True)

# %%
#clean_data.drop('level_0',axis=1,inplace=True)

# %%
clean_data.drop('index',axis=1,inplace=True)

# %%
clean_data.head(50)
# Out:
#         Date   Voucher                Party              Product       Qty  \
# 0   1/4/2017     Sal:1     SOLANKI PLASTICS        DONA-VAI-9100         2
# 1   1/4/2017     Sal:1     SOLANKI PLASTICS      LITE FOAM(1200)         6
# 2   1/4/2017     Sal:2   SARNESWARA TRADERS    VISHNU CHOTA WINE       500
# 3   1/4/2017     Sal:2   SARNESWARA TRADERS      LITE FOAM(1200)         6
# 4   1/4/2017     Sal:2   SARNESWARA TRADERS        DONA-VAI-9100         5
# 5   1/4/2017     Sal:2   SARNESWARA TRADERS   CLASSIC ENJOY(750)         1
# 6   1/4/2017   Sal:898                 Lock         Vishnu 250ml       100
# 7   1/4/2017   Sal:898                 Lock      BLACK DOG-350ML       100
# 8   1/4/2017  Sal:2497  VAMSI KRISHNA FANCY          Loose Items         1
# 9   1/4/2017  Sal:9263  VAMSI KRISHNA FANCY          Loose Items         1
# 10  1/4/2017  Sal:9545                  Vkp          Loose Items         1
# ...

# %%
clean_data.shape
# Out:
# (95561, 6)

# %%
clean_data1 = clean_data
clean_data1
# Out:
#              Date   Voucher               Party              Product  Qty  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...           ...       ...                 ...                  ...  ...
# 95556  10/10/2019  Sal:4935           K.SRIHARI         16*20(100-W)  140
# 95557  10/10/2019  Sal:4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 95558  10/10/2019  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 95559  10/10/2019  Sal:4935           K.SRIHARI             10*12 RK  800
# 95560  10/10/2019  Sal:4935           K.SRIHARI       13*16 WHITE RK  400
#
#            Rate
# 0      1,690.00
# 1      1,620.00
# 2            23
# ...

# %% [markdown]
# ## Now converting the datatype

# %%
clean_data1.dtypes
# Out:
# Date       datetime64[ns]
# Voucher             int32
# Party              object
# Product            object
# Qty               float64
# Rate              float64
# dtype: object

# %%
clean_data1['Qty']=clean_data['Qty'].str.replace(',','')  # 1st replaced the (,) with () in db

# %%
clean_data1['Qty']=clean_data['Qty'].astype(int)    # converted the datatye in int

# %%
clean_data1.head()
# Out:
#        Date  Voucher               Party            Product    Qty      Rate
# 0  1/4/2017        1    SOLANKI PLASTICS      DONA-VAI-9100    2.0  1,690.00
# 1  1/4/2017        1    SOLANKI PLASTICS    LITE FOAM(1200)    6.0  1,620.00
# 2  1/4/2017        2  SARNESWARA TRADERS  VISHNU CHOTA WINE  500.0        23
# 3  1/4/2017        2  SARNESWARA TRADERS    LITE FOAM(1200)    6.0  1,620.00
# 4  1/4/2017        2  SARNESWARA TRADERS      DONA-VAI-9100    5.0  1,690.00

# %%
clean_data['Voucher']=clean_data['Voucher'].str.replace('Sal:','')    # 1st replaced the (Sal:) with () in db

# %%
clean_data['Voucher']=clean_data['Voucher'].astype(int)   #conveted the datatype as int

# %%
# clean_data1.drop('Vocher',axis= 1,inplace=True)        # accidently created the Vocher column so deleted it

# %%
clean_data1['Rate']=clean_data1['Rate'].str.replace(',','')

# %%
clean_data1['Rate']=clean_data1['Rate'].astype(float)

# %%
clean_data1['Date']=pd.to_datetime(clean_data1['Date'])
# Out:
# C:\Users\shubham\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\shubham\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\shubham\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15/04/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
clean_data1
# Out:
#             Date  Voucher               Party              Product    Qty  \
# 0     2017-01-04        1    SOLANKI PLASTICS        DONA-VAI-9100    2.0
# 1     2017-01-04        1    SOLANKI PLASTICS      LITE FOAM(1200)    6.0
# 2     2017-01-04        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500.0
# 3     2017-01-04        2  SARNESWARA TRADERS      LITE FOAM(1200)    6.0
# 4     2017-01-04        2  SARNESWARA TRADERS        DONA-VAI-9100    5.0
# ...          ...      ...                 ...                  ...    ...
# 95556 2019-10-10     4935           K.SRIHARI         16*20(100-W)  140.0
# 95557 2019-10-10     4935           K.SRIHARI  10*12 KRISHNA-BK(10  600.0
# 95558 2019-10-10     4935           K.SRIHARI  13*16 Bk(100)KRISHN  320.0
# 95559 2019-10-10     4935           K.SRIHARI             10*12 RK  800.0
# 95560 2019-10-10     4935           K.SRIHARI       13*16 WHITE RK  400.0
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# ...

# %%
clean_data1.isnull().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       0
# dtype: int64

# %%
clean_data1.dtypes
# Out:
# Date       datetime64[ns]
# Voucher             int32
# Party              object
# Product            object
# Qty                 int32
# Rate              float64
# dtype: object

# %%
clean_data1
# Out:
#             Date  Voucher               Party              Product  Qty  \
# 0     2017-01-04        1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1     2017-01-04        1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2     2017-01-04        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3     2017-01-04        2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4     2017-01-04        2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...          ...      ...                 ...                  ...  ...
# 95556 2019-10-10     4935           K.SRIHARI         16*20(100-W)  140
# 95557 2019-10-10     4935           K.SRIHARI  10*12 KRISHNA-BK(10  600
# 95558 2019-10-10     4935           K.SRIHARI  13*16 Bk(100)KRISHN  320
# 95559 2019-10-10     4935           K.SRIHARI             10*12 RK  800
# 95560 2019-10-10     4935           K.SRIHARI       13*16 WHITE RK  400
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# 4      1690.0
# ...

# %%
clean_data1.to_csv('Clean_data.csv')

# %% [markdown]
# # ----------------------------------END---------------------------------------
